# %%
import pickle
import matplotlib.pyplot as plt

# %%
def rank3_cpd_plots(factor_dir, chromosome):
    # Create 9 subplots arranged vertically
    fig, axs = plt.subplots(9, 1, figsize=(10, 30))
    # hspace is the amount of height reserved for white space between subplots
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    # List of parameter sets to plot (1 to 9)
    param_sets = list(range(1, 10))

    for i, p in enumerate(param_sets):
        # Incorporate the chromosome number into the file name
        file_name = f'{chromosome}_rank3_paramset{p}_factors_100kb.pickle'
        file_path = factor_dir + file_name

        with open(file_path, 'rb') as file:
            factor_matrices = pickle.load(file)

        factor_matrix_1 = factor_matrices[0]

        # Use the i-th subplot for each plot
        ax = axs[i]

        # Create the plot in the specified subplot
        ax.plot(factor_matrix_1[:, 0], label='Rank 1')
        ax.plot(factor_matrix_1[:, 1], label='Rank 2')
        ax.plot(factor_matrix_1[:, 2], label='Rank 3')

        # Set titles for each paramset
        if i == 0: 
            ax.set_title('Default CPD Parameters', fontsize=12)
            ax.legend(loc='upper right', fontsize=10)
        elif i == 1:
            ax.set_title("'Smart Random' Initialization", fontsize=12)
        elif i == 2:
            ax.set_title("'Smart' Initialization", fontsize=12)
        elif i == 3:
            ax.set_title("ALS Method", fontsize=12)
        elif i == 4:
            ax.set_title("ALS Method, CG Static Inner Method", fontsize=12)
        elif i == 5:
            ax.set_title("High Tolerance", fontsize=12)
        elif i == 6:
            ax.set_title("Direct Inner Method", fontsize=12)
        elif i == 7:
            ax.set_title("CG Static Inner Method", fontsize=12)
        elif i == 8:
            ax.set_title("ALS Inner Method", fontsize=12)

        # Adjust axis labels
        if p == 9:
            ax.set_xlabel('Genomic Bins', fontsize=10)
        ax.set_ylabel('Factor Values', fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
factor_dir = '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/output/factors/'
rank3_cpd_plots(factor_dir, "chr21")

# %%
def rank4_cpd_plots(factor_dir, chromosome):
    # Create 9 subplots arranged vertically
    fig, axs = plt.subplots(9, 1, figsize=(10, 30))
    # hspace is the amount of height reserved for white space between subplots
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    # List of parameter sets to plot (1 to 9)
    param_sets = list(range(1, 10))

    for i, p in enumerate(param_sets):
        # Incorporate the chromosome number into the file name
        file_name = f'{chromosome}_rank4_paramset{p}_factors_100kb.pickle'
        file_path = factor_dir + file_name

        with open(file_path, 'rb') as file:
            factor_matrices = pickle.load(file)

        factor_matrix_1 = factor_matrices[0]

        # Use the i-th subplot for each plot
        ax = axs[i]

        # Create the plot in the specified subplot
        ax.plot(factor_matrix_1[:, 0], label='Rank 1')
        ax.plot(factor_matrix_1[:, 1], label='Rank 2')
        ax.plot(factor_matrix_1[:, 2], label='Rank 3')
        ax.plot(factor_matrix_1[:, 3], label='Rank 4')

        # Set titles for each paramset
        if i == 0: 
            ax.set_title('Default CPD Parameters', fontsize=12)
            ax.legend(loc='upper right', fontsize=10)
        elif i == 1:
            ax.set_title("'Smart Random' Initialization", fontsize=12)
        elif i == 2:
            ax.set_title("'Smart' Initialization", fontsize=12)
        elif i == 3:
            ax.set_title("ALS Method", fontsize=12)
        elif i == 4:
            ax.set_title("ALS Method, CG Static Inner Method", fontsize=12)
        elif i == 5:
            ax.set_title("High Tolerance", fontsize=12)
        elif i == 6:
            ax.set_title("Direct Inner Method", fontsize=12)
        elif i == 7:
            ax.set_title("CG Static Inner Method", fontsize=12)
        elif i == 8:
            ax.set_title("ALS Inner Method", fontsize=12)

        # Adjust axis labels
        if p == 9:
            ax.set_xlabel('Genomic Bins', fontsize=10)
        ax.set_ylabel('Factor Values', fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
rank4_cpd_plots(factor_dir, "chr21")

# %%
def rank5_cpd_plots(factor_dir, chromosome):
    # Create 9 subplots arranged vertically
    fig, axs = plt.subplots(9, 1, figsize=(10, 30))
    # hspace is the amount of height reserved for white space between subplots
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    # List of parameter sets to plot (1 to 9)
    param_sets = list(range(1, 10))

    for i, p in enumerate(param_sets):
        # Incorporate the chromosome number into the file name
        file_name = f'{chromosome}_rank5_paramset{p}_factors_100kb.pickle'
        file_path = factor_dir + file_name

        with open(file_path, 'rb') as file:
            factor_matrices = pickle.load(file)

        factor_matrix_1 = factor_matrices[0]

        # Use the i-th subplot for each plot
        ax = axs[i]

        # Create the plot in the specified subplot
        ax.plot(factor_matrix_1[:, 0], label='Rank 1')
        ax.plot(factor_matrix_1[:, 1], label='Rank 2')
        ax.plot(factor_matrix_1[:, 2], label='Rank 3')
        ax.plot(factor_matrix_1[:, 3], label='Rank 4')
        ax.plot(factor_matrix_1[:, 4], label='Rank 5')

        # Set titles for each paramset
        if i == 0: 
            ax.set_title('Default CPD Parameters', fontsize=12)
            ax.legend(loc='upper right', fontsize=10)
        elif i == 1:
            ax.set_title("'Smart Random' Initialization", fontsize=12)
        elif i == 2:
            ax.set_title("'Smart' Initialization", fontsize=12)
        elif i == 3:
            ax.set_title("ALS Method", fontsize=12)
        elif i == 4:
            ax.set_title("ALS Method, CG Static Inner Method", fontsize=12)
        elif i == 5:
            ax.set_title("High Tolerance", fontsize=12)
        elif i == 6:
            ax.set_title("Direct Inner Method", fontsize=12)
        elif i == 7:
            ax.set_title("CG Static Inner Method", fontsize=12)
        elif i == 8:
            ax.set_title("ALS Inner Method", fontsize=12)

        # Adjust axis labels
        if p == 9:
            ax.set_xlabel('Genomic Bins', fontsize=10)
        ax.set_ylabel('Factor Values', fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
rank5_cpd_plots(factor_dir, "chr21")

# %%
def rank6_cpd_plots(factor_dir, chromosome):
    # Create 9 subplots arranged vertically
    fig, axs = plt.subplots(9, 1, figsize=(10, 30))
    # hspace is the amount of height reserved for white space between subplots
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    # List of parameter sets to plot (1 to 9)
    param_sets = list(range(1, 10))

    for i, p in enumerate(param_sets):
        # Incorporate the chromosome number into the file name
        file_name = f'{chromosome}_rank6_paramset{p}_factors_100kb.pickle'
        file_path = factor_dir + file_name

        with open(file_path, 'rb') as file:
            factor_matrices = pickle.load(file)

        factor_matrix_1 = factor_matrices[0]

        # Use the i-th subplot for each plot
        ax = axs[i]

        # Create the plot in the specified subplot
        ax.plot(factor_matrix_1[:, 0], label='Rank 1')
        ax.plot(factor_matrix_1[:, 1], label='Rank 2')
        ax.plot(factor_matrix_1[:, 2], label='Rank 3')
        ax.plot(factor_matrix_1[:, 3], label='Rank 4')
        ax.plot(factor_matrix_1[:, 4], label='Rank 5')
        ax.plot(factor_matrix_1[:, 5], label='Rank 6')

        # Set titles for each paramset
        if i == 0: 
            ax.set_title('Default CPD Parameters', fontsize=12)
            ax.legend(loc='upper right', fontsize=10)
        elif i == 1:
            ax.set_title("'Smart Random' Initialization", fontsize=12)
        elif i == 2:
            ax.set_title("'Smart' Initialization", fontsize=12)
        elif i == 3:
            ax.set_title("ALS Method", fontsize=12)
        elif i == 4:
            ax.set_title("ALS Method, CG Static Inner Method", fontsize=12)
        elif i == 5:
            ax.set_title("High Tolerance", fontsize=12)
        elif i == 6:
            ax.set_title("Direct Inner Method", fontsize=12)
        elif i == 7:
            ax.set_title("CG Static Inner Method", fontsize=12)
        elif i == 8:
            ax.set_title("ALS Inner Method", fontsize=12)

        # Adjust axis labels
        if p == 9:
            ax.set_xlabel('Genomic Bins', fontsize=10)
        ax.set_ylabel('Factor Values', fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
rank6_cpd_plots(factor_dir, "chr21")

# %%
def rank7_cpd_plots(factor_dir, chromosome):
    # Create 9 subplots arranged vertically
    fig, axs = plt.subplots(9, 1, figsize=(10, 30))
    # hspace is the amount of height reserved for white space between subplots
    fig.subplots_adjust(hspace=0.1, wspace=0.1)

    # List of parameter sets to plot (1 to 9)
    param_sets = list(range(1, 10))

    for i, p in enumerate(param_sets):
        # Incorporate the chromosome number into the file name
        file_name = f'{chromosome}_rank7_paramset{p}_factors_100kb.pickle'
        file_path = factor_dir + file_name

        with open(file_path, 'rb') as file:
            factor_matrices = pickle.load(file)

        factor_matrix_1 = factor_matrices[0]

        # Use the i-th subplot for each plot
        ax = axs[i]

        # Create the plot in the specified subplot
        ax.plot(factor_matrix_1[:, 0], label='Rank 1')
        ax.plot(factor_matrix_1[:, 1], label='Rank 2')
        ax.plot(factor_matrix_1[:, 2], label='Rank 3')
        ax.plot(factor_matrix_1[:, 3], label='Rank 4')
        ax.plot(factor_matrix_1[:, 4], label='Rank 5')
        ax.plot(factor_matrix_1[:, 5], label='Rank 6')
        ax.plot(factor_matrix_1[:, 6], label='Rank 7')

        # Set titles for each paramset
        if i == 0: 
            ax.set_title('Default CPD Parameters', fontsize=12)
            ax.legend(loc='upper right', fontsize=10)
        elif i == 1:
            ax.set_title("'Smart Random' Initialization", fontsize=12)
        elif i == 2:
            ax.set_title("'Smart' Initialization", fontsize=12)
        elif i == 3:
            ax.set_title("ALS Method", fontsize=12)
        elif i == 4:
            ax.set_title("ALS Method, CG Static Inner Method", fontsize=12)
        elif i == 5:
            ax.set_title("High Tolerance", fontsize=12)
        elif i == 6:
            ax.set_title("Direct Inner Method", fontsize=12)
        elif i == 7:
            ax.set_title("CG Static Inner Method", fontsize=12)
        elif i == 8:
            ax.set_title("ALS Inner Method", fontsize=12)

        # Adjust axis labels
        if p == 9:
            ax.set_xlabel('Genomic Bins', fontsize=10)
        ax.set_ylabel('Factor Values', fontsize=10)

    plt.tight_layout()
    plt.show()

# %%
rank7_cpd_plots(factor_dir, "chr21")

# %% [markdown]
# ## Tensor-Based Analysis of High-Order Chromatin Interactions in Pore-C Data
#
# ### Initial setup:
#  - Use the following commands to install a Conda/Miniconda env for running TensorFox
#  - https://github.com/felipebottega/Tensor-Fox for more details
#
# ```bash
# pip install TensorFox
# conda create --name tfx_env --channel defaults jupyter numpy pandas scipy scikit-learn matplotlib numba IPython sparse_dot_mkl
# ```
#
# ### Protocol for creating and factorizing high-dimensional tensors (i.e. not 2D)
# Slurm scripts are in '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/scripts/slurm_jobs' \
# The corresponding Python scripts are in '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/scripts/python_code' \
# ```bash
# cd /commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/scripts/slurm_jobs
# ```
#
# To create tensors for Pore-C data:
# ```bash
# sbatch make_tensors.slurm
# ```
#  - Make sure that make_tensors.slurm finishes before running the CPD job
#  - You can check the log file here: '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/output/make_tensors_log_slurm_{job_number}.txt
#  - The tensors are saved in '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/output/tensors/'
#  - You can change the parameters at the top of the make_tensors.py script
#  - You may have to modify the memory allocation at the top of the slurm script
#     - Using a smaller window size will require more memory
#     - Creating tensors for larger chromosomes will require more memory
#     - Using a higher maximum cardinality will require *way* more memory
#
# To perform CPD on the tensors:
# ```bash
# sbatch cpd.slurm
# ```
#  - You can check the log file here: '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/output/cpd_log_slurm_{job_number}.txt
#  - The factors will be saved in '/commons/groups/gursoy_lab/wlounsberyscaife/PoreC_Tensors/output/factors/'
#
#  To plot the factors, you can use the jupyter notebook 'scripts/jupyter_notebooks/cpd_results.ipynb/cpd_results.ipynb'
